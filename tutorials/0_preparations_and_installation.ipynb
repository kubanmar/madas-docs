# %% [markdown]
# # Preparations and installation

# %% [markdown]
# To follow the tutorials, it is strongly suggested to use a virtual environment management, such as [Python venv](https://docs.python.org/3/library/venv.html), or more powerfull package managers like [uv](https://docs.astral.sh/uv/).
#
# For running the tutorials, you can move to some path on your machine that is suitable for this:
#
# ```bash
# cd /path/to/tutorials
# ```

# %% [markdown]
# ## Using Python venv

# %% [markdown]
# Create a virtual environment and activate it by typing
# ```bash
# python3 -m venv .venv
# source .venv/bin/activate
# ```
# Next, you need to install MADAS:
# ```bash
# pip install madas
# ```

# %% [markdown]
# ### Following along in the command line

# %% [markdown]
# If you want to follow the tutorials in the command line, after activating your virtual environment, you can run a Python interpreter:
#
# ```bash
# python
# ```
# and copy the commands from the MADAS website.

# %% [markdown]
# ### Running the notebooks locally

# %% [markdown]
# For running the notebooks locally, you first need to install `jupyter`:
# ```bash
# pip install jupyter
# ```
#
# Then, download the tutorials from https://madas.readthedocs.io/en/latest/tutorials.html
# and save them at the same path where your virtual environment is.
#
# Run
# ```bash
# jupyter notebook
# ```
# to open jupyter and click on the tutorial that you want to do.

# %% [markdown]
# ## Using uv

# %% [markdown]
# Make sure you have [installed uv](https://docs.astral.sh/uv/getting-started/installation/).

# %% [markdown]
# Create a virtual environment and activate it by typing
# ```bash
# uv venv
# source .venv/bin/activate
# ```
# Next, you need to install MADAS:
# ```bash
# uv pip install madas
# ```

# %% [markdown]
# ### Following along in the command line

# %% [markdown]
# If you want to follow the tutorials in the command line, after activating your virtual environment, you can run a Python interpreter:
#
# ```bash
# uv run python
# ```
# and copy the commands from the MADAS website.

# %% [markdown]
# ### Running the notebooks locally

# %% [markdown]
# For running the notebooks locally, you first need to install `jupyter`:
# ```bash
# uv pip install jupyter
# ```
#
# Then, download the tutorials from https://madas.readthedocs.io/en/latest/tutorials.html
# and save them at the same path where your virtual environment is.
#
# Run
# ```bash
# uv run jupyter notebook
# ```
# to open jupyter and click on the tutorial that you want to do.
