# %% [markdown]
# # Writing custom API interfaces

# %% [markdown]
# Coming soon
#
# In the meantime, you can use [example notebooks on github](https://github.com/kubanmar/madas-examples/blob/master/notebooks/comparing_web_databases_volumes.ipynb) as a template.
